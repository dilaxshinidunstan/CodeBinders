# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re
import json
import nltk
from nltk.corpus import stopwords
from textblob import TextBlob
from sklearn.preprocessing import MinMaxScaler
from prophet import Prophet
from nltk.tokenize import TreebankWordTokenizer

import pandas as pd
import json
import re

def generate_trending_keywords():
    # Optional NLTK downloads
    nltk.download('punkt')
    nltk.download('stopwords')

    # Load data
    df_search = pd.read_csv('/content/drive/MyDrive/HackFest_Dataset/search_trends.csv')
    df_sales = pd.read_csv('/content/drive/MyDrive/HackFest_Dataset/sales_data.csv')
    df_feedback = pd.read_csv('/content/drive/MyDrive/HackFest_Dataset/customer_feedback.csv')
    df_catalog = pd.read_csv('/content/drive/MyDrive/HackFest_Dataset/product_catalog.csv')

    # Convert dates
    df_search['timestamp'] = pd.to_datetime(df_search['timestamp'])
    df_sales['timestamp'] = pd.to_datetime(df_sales['timestamp'])
    df_feedback['date'] = pd.to_datetime(df_feedback['date'])

    # Preprocess search queries
    stop_words = set(stopwords.words('english'))
    tokenizer = TreebankWordTokenizer()

    def clean_and_tokenize(query):
        query = re.sub(r'[^a-zA-Z\s]', '', str(query).lower())
        tokens = tokenizer.tokenize(query)
        return [word for word in tokens if word not in stop_words]

    df_search['tokens'] = df_search['query'].apply(clean_and_tokenize)
    df_exploded = df_search.explode('tokens')
    df_exploded = df_exploded.rename(columns={'tokens': 'keyword'})

    # Aggregate keyword frequency
    df_token_time = df_exploded.groupby(['timestamp', 'keyword'])['frequency'].sum().reset_index()

    # --- SALES DATA ---
    product_category_map = dict(zip(df_catalog['productId'], df_catalog['category']))
    df_sales['domain'] = df_sales['productId'].map(product_category_map)

    df_sales_agg = df_sales.groupby(['timestamp', 'domain'])['quantitySold'].sum().reset_index()
    df_sales_agg.rename(columns={'quantitySold': 'totalSales'}, inplace=True)

    # --- CUSTOMER FEEDBACK ---
    df_feedback['sentiment'] = df_feedback['commentText'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
    df_feedback['domain'] = df_feedback['productId'].map(product_category_map)

    df_sentiment = df_feedback.groupby(['date', 'domain'])['sentiment'].mean().reset_index()
    df_sentiment.rename(columns={'date': 'timestamp', 'sentiment': 'avgSentiment'}, inplace=True)

    # --- Map keywords to domain ---
    catalog_keywords = set()
    for col in ['title', 'category', 'modifiers', 'keywords']:
        text = " ".join(df_catalog[col].dropna().astype(str).str.lower())
        catalog_keywords.update(tokenizer.tokenize(text))
    catalog_keywords = list(catalog_keywords)

    def guess_domain(token):
        for domain in df_catalog['category'].unique():
            if token in domain.lower():
                return domain
        return 'unknown'

    df_token_time['domain'] = df_token_time['keyword'].apply(guess_domain)

    # Merge with sales and sentiment
    df_all = df_token_time.merge(df_sales_agg, on=['timestamp', 'domain'], how='left')
    df_all = df_all.merge(df_sentiment, on=['timestamp', 'domain'], how='left')
    df_all['totalSales'] = df_all['totalSales'].fillna(0)
    df_all['avgSentiment'] = df_all['avgSentiment'].fillna(0)

    # Normalize features
    scaler = MinMaxScaler()
    df_all[['frequency_norm', 'sales_norm', 'sentiment_norm']] = scaler.fit_transform(
        df_all[['frequency', 'totalSales', 'avgSentiment']]
    )

    # Compute composite score
    w_search, w_sales, w_sentiment = 0.5, 0.3, 0.2
    df_all['composite_score'] = (
        w_search * df_all['frequency_norm'] +
        w_sales * df_all['sales_norm'] +
        w_sentiment * df_all['sentiment_norm']
    )

    # --- Forecasting ---
    forecast_dict = {}
    top_keywords = df_all.groupby('keyword')['composite_score'].sum().sort_values(ascending=False).head(50).index.tolist()

    for keyword in top_keywords:
        sub_df = df_all[df_all['keyword'] == keyword][['timestamp', 'composite_score']]
        sub_df = sub_df.rename(columns={'timestamp': 'ds', 'composite_score': 'y'})

        if len(sub_df) >= 5:
            model = Prophet(daily_seasonality=True)
            model.fit(sub_df)

            future = model.make_future_dataframe(periods=7)
            forecast = model.predict(future)

            total_future_score = forecast.tail(7)['yhat'].sum()
            forecast_dict[keyword] = total_future_score

    # Sort and save top 20 trending keywords
    sorted_keywords = sorted(forecast_dict.items(), key=lambda x: x[1], reverse=True)
    top_keywords_output = [{'keyword': kw, 'forecast_score': round(score, 2)} for kw, score in sorted_keywords[:20]]

    with open('/content/drive/MyDrive/HackFest_Dataset/toptrendingkeywords.json', 'w') as f:
        json.dump(top_keywords_output, f, indent=4)

    print("✅ Saved top trending keywords to toptrendingkeywords.json")

# You can call this function to run
# generate_trending_keywords()



def generate_recommendations():
    # 1. Load trending keywords
    with open('/content/drive/MyDrive/HackFest_Dataset/toptrendingkeywords.json', 'r') as f:
        trending_keywords = json.load(f)

    # Convert to DataFrame
    df_trending = pd.DataFrame(trending_keywords)

    # 2. Load product catalog
    df_catalog = pd.read_csv('/content/drive/MyDrive/HackFest_Dataset/product_catalog.csv')

    # Fill NaNs with empty strings to avoid issues
    df_catalog.fillna('', inplace=True)

    # 3. Combine product details for matching
    df_catalog['combined_text'] = (
        df_catalog['title'].astype(str) + ' ' +
        df_catalog['category'].astype(str) + ' ' +
        df_catalog['modifiers'].astype(str) + ' ' +
        df_catalog['keywords'].astype(str)
    ).str.lower()

    # 4. Match products to trending keywords
    matched_products = []

    for _, row in df_trending.iterrows():
        keyword = row['keyword'].lower()
        score = row['forecast_score']

        # Find products containing the keyword
        matches = df_catalog[df_catalog['combined_text'].str.contains(rf'\b{re.escape(keyword)}\b', regex=True)].copy()
        matches['matched_keyword'] = keyword
        matches['forecast_score'] = score

        matched_products.append(matches)

    # 5. Concatenate all matched products
    if matched_products:
        df_matched_products = pd.concat(matched_products, ignore_index=True)

        # Optional: sort by forecast score
        df_matched_products = df_matched_products.sort_values(by='forecast_score', ascending=False)

        # 6. Save or display the top results
        df_matched_products[['productId', 'title', 'category', 'matched_keyword', 'forecast_score']].to_csv('/content/drive/MyDrive/HackFest_Dataset/recommended_products.csv', index=False)

        print("Recommended products saved to recommended_products.csv")
    else:
        print("No products matched the trending keywords.")
  # generate_trend()

# %%
generate_trending_keywords()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/3t6lx9b2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/jc0n2awq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13535', 'data', 'file=/tmp/tmpym6s_hsl/3t6lx9b2.json', 'init=/tmp/tmpym6s_hsl/jc0n2awq.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelahl_a5jn/prophet_model-20250531094927.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/lm5jxoq6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/rbo_rxx9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65323', 'data', 'file=/tmp/tmpym6s_hsl/lm5jxoq6.json', 'init=/tmp/tmpym6s_hsl/rbo_rxx9.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelnkca0zft/prophet_model-20250531094928.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/l3twtqf8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/87gpaxjb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80278', 'data', 'file=/tmp/tmpym6s_hsl/l3twtqf8.json', 'init=/tmp/tmpym6s_hsl/87gpaxjb.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model1lxb1ntm/prophet_model-20250531094928.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/l7ijb96r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/0yp8sepo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38328', 'data', 'file=/tmp/tmpym6s_hsl/l7ijb96r.json', 'init=/tmp/tmpym6s_hsl/0yp8sepo.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelnjz6jlgs/prophet_model-20250531094929.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/gylzx7yy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/panqd7m0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28136', 'data', 'file=/tmp/tmpym6s_hsl/gylzx7yy.json', 'init=/tmp/tmpym6s_hsl/panqd7m0.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelyr1gajyl/prophet_model-20250531094930.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/d4yxbvot.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/irc3376s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96753', 'data', 'file=/tmp/tmpym6s_hsl/d4yxbvot.json', 'init=/tmp/tmpym6s_hsl/irc3376s.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model6ysbcuyd/prophet_model-20250531094930.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/q7tmkt5_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/vc92jxkt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88535', 'data', 'file=/tmp/tmpym6s_hsl/q7tmkt5_.json', 'init=/tmp/tmpym6s_hsl/vc92jxkt.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model0olc260i/prophet_model-20250531094931.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/93oers0z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/9hqh4dsr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43883', 'data', 'file=/tmp/tmpym6s_hsl/93oers0z.json', 'init=/tmp/tmpym6s_hsl/9hqh4dsr.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelm31e4cmt/prophet_model-20250531094932.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/ywzm8r42.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/0fjez_9t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33842', 'data', 'file=/tmp/tmpym6s_hsl/ywzm8r42.json', 'init=/tmp/tmpym6s_hsl/0fjez_9t.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelg5oskkob/prophet_model-20250531094932.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/8i5slewt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/d1sj1spw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23349', 'data', 'file=/tmp/tmpym6s_hsl/8i5slewt.json', 'init=/tmp/tmpym6s_hsl/d1sj1spw.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelep3cqgth/prophet_model-20250531094933.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/cgiezuf3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/8xz1mx_z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25731', 'data', 'file=/tmp/tmpym6s_hsl/cgiezuf3.json', 'init=/tmp/tmpym6s_hsl/8xz1mx_z.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelhmq7b1fh/prophet_model-20250531094933.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/lvdj916x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/wydvs3ud.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44119', 'data', 'file=/tmp/tmpym6s_hsl/lvdj916x.json', 'init=/tmp/tmpym6s_hsl/wydvs3ud.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model2uu5_y5a/prophet_model-20250531094934.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/fwh5qjxp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/rbvk3j9y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84918', 'data', 'file=/tmp/tmpym6s_hsl/fwh5qjxp.json', 'init=/tmp/tmpym6s_hsl/rbvk3j9y.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelmreczq0_/prophet_model-20250531094934.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/odzh3v3h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/15kd4z0t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58455', 'data', 'file=/tmp/tmpym6s_hsl/odzh3v3h.json', 'init=/tmp/tmpym6s_hsl/15kd4z0t.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model0ci79cmf/prophet_model-20250531094935.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/10_iyxnl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/d07fb4pj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74400', 'data', 'file=/tmp/tmpym6s_hsl/10_iyxnl.json', 'init=/tmp/tmpym6s_hsl/d07fb4pj.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelj4wi86oe/prophet_model-20250531094935.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/9z013vt1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/_x_lwrlj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90406', 'data', 'file=/tmp/tmpym6s_hsl/9z013vt1.json', 'init=/tmp/tmpym6s_hsl/_x_lwrlj.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelzowf75kf/prophet_model-20250531094935.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/3__l_cin.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/9nz_faes.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4102', 'data', 'file=/tmp/tmpym6s_hsl/3__l_cin.json', 'init=/tmp/tmpym6s_hsl/9nz_faes.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model0ym5gvj1/prophet_model-20250531094936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/bn9k2i4y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/u_wry54b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27680', 'data', 'file=/tmp/tmpym6s_hsl/bn9k2i4y.json', 'init=/tmp/tmpym6s_hsl/u_wry54b.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelb5_qn01y/prophet_model-20250531094936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/o76l5_f1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/22rvjrze.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93548', 'data', 'file=/tmp/tmpym6s_hsl/o76l5_f1.json', 'init=/tmp/tmpym6s_hsl/22rvjrze.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelsmq9x9zh/prophet_model-20250531094937.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/szkqrh8c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/1n49w9ob.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70793', 'data', 'file=/tmp/tmpym6s_hsl/szkqrh8c.json', 'init=/tmp/tmpym6s_hsl/1n49w9ob.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelpnxx48ef/prophet_model-20250531094937.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/feeeqy1n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/8wxzynq8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43929', 'data', 'file=/tmp/tmpym6s_hsl/feeeqy1n.json', 'init=/tmp/tmpym6s_hsl/8wxzynq8.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelavqjucms/prophet_model-20250531094938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/n5gjgrg4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/rp82y9om.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46655', 'data', 'file=/tmp/tmpym6s_hsl/n5gjgrg4.json', 'init=/tmp/tmpym6s_hsl/rp82y9om.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelpabowmv5/prophet_model-20250531094938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/q8byygw2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/o_5d7_y2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11066', 'data', 'file=/tmp/tmpym6s_hsl/q8byygw2.json', 'init=/tmp/tmpym6s_hsl/o_5d7_y2.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelsj52wmm1/prophet_model-20250531094938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/rtdixjnk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/eskks3ae.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61200', 'data', 'file=/tmp/tmpym6s_hsl/rtdixjnk.json', 'init=/tmp/tmpym6s_hsl/eskks3ae.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelc5oefrg4/prophet_model-20250531094939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/1vxaq4ba.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/g8rdkwrv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82877', 'data', 'file=/tmp/tmpym6s_hsl/1vxaq4ba.json', 'init=/tmp/tmpym6s_hsl/g8rdkwrv.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model0ply431j/prophet_model-20250531094939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/hzek46pm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/mxml4_9h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63281', 'data', 'file=/tmp/tmpym6s_hsl/hzek46pm.json', 'init=/tmp/tmpym6s_hsl/mxml4_9h.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modeljv9s8ts8/prophet_model-20250531094940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/5q3gqn73.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/vjos2qoz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66016', 'data', 'file=/tmp/tmpym6s_hsl/5q3gqn73.json', 'init=/tmp/tmpym6s_hsl/vjos2qoz.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelw9p8gs2_/prophet_model-20250531094940.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/ir7m813u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/0le1jvqg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76483', 'data', 'file=/tmp/tmpym6s_hsl/ir7m813u.json', 'init=/tmp/tmpym6s_hsl/0le1jvqg.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model8pkmncp9/prophet_model-20250531094941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/g9yi7ump.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/4cvwbp9o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12062', 'data', 'file=/tmp/tmpym6s_hsl/g9yi7ump.json', 'init=/tmp/tmpym6s_hsl/4cvwbp9o.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelcw65ljpb/prophet_model-20250531094941.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/a609ibm8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/qbk873k9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40277', 'data', 'file=/tmp/tmpym6s_hsl/a609ibm8.json', 'init=/tmp/tmpym6s_hsl/qbk873k9.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelj2vsob_s/prophet_model-20250531094942.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/yg8s8pjx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/_tzvlkcd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30776', 'data', 'file=/tmp/tmpym6s_hsl/yg8s8pjx.json', 'init=/tmp/tmpym6s_hsl/_tzvlkcd.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model1ti8f8hg/prophet_model-20250531094942.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/5k300eop.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/faohhz2x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43027', 'data', 'file=/tmp/tmpym6s_hsl/5k300eop.json', 'init=/tmp/tmpym6s_hsl/faohhz2x.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model1ztdv5jz/prophet_model-20250531094943.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/ukud1guz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/kc4x10ru.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17539', 'data', 'file=/tmp/tmpym6s_hsl/ukud1guz.json', 'init=/tmp/tmpym6s_hsl/kc4x10ru.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelw844e2hq/prophet_model-20250531094944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/4hdda6hc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/upmx20vn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30558', 'data', 'file=/tmp/tmpym6s_hsl/4hdda6hc.json', 'init=/tmp/tmpym6s_hsl/upmx20vn.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modeltqh8146v/prophet_model-20250531094944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/9_e9x7jx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/v1e2tka2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84146', 'data', 'file=/tmp/tmpym6s_hsl/9_e9x7jx.json', 'init=/tmp/tmpym6s_hsl/v1e2tka2.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model6jb1pxyc/prophet_model-20250531094945.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/fb4ub1vo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/oax7y0v1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34858', 'data', 'file=/tmp/tmpym6s_hsl/fb4ub1vo.json', 'init=/tmp/tmpym6s_hsl/oax7y0v1.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model2ba2o748/prophet_model-20250531094945.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/ywghml2m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/b6etf2jn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23986', 'data', 'file=/tmp/tmpym6s_hsl/ywghml2m.json', 'init=/tmp/tmpym6s_hsl/b6etf2jn.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model587ipf8a/prophet_model-20250531094946.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/bfh_wyug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/yks506jz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24433', 'data', 'file=/tmp/tmpym6s_hsl/bfh_wyug.json', 'init=/tmp/tmpym6s_hsl/yks506jz.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelz5glaeno/prophet_model-20250531094946.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/t2f7c7cv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/ydkkfka6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79109', 'data', 'file=/tmp/tmpym6s_hsl/t2f7c7cv.json', 'init=/tmp/tmpym6s_hsl/ydkkfka6.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelf3ku8npd/prophet_model-20250531094947.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/3tk4pn8y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/4odoqmny.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36294', 'data', 'file=/tmp/tmpym6s_hsl/3tk4pn8y.json', 'init=/tmp/tmpym6s_hsl/4odoqmny.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelo2uksaeq/prophet_model-20250531094947.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/tz6suja0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/qo24z_gy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66679', 'data', 'file=/tmp/tmpym6s_hsl/tz6suja0.json', 'init=/tmp/tmpym6s_hsl/qo24z_gy.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelycc1op37/prophet_model-20250531094947.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/t07cgzh0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/2n6rifmr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56957', 'data', 'file=/tmp/tmpym6s_hsl/t07cgzh0.json', 'init=/tmp/tmpym6s_hsl/2n6rifmr.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model1jverher/prophet_model-20250531094948.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/i4mjncpp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/90uuohl3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6174', 'data', 'file=/tmp/tmpym6s_hsl/i4mjncpp.json', 'init=/tmp/tmpym6s_hsl/90uuohl3.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model4w0p_riw/prophet_model-20250531094948.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/jm0apmlk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/1suhjerf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3511', 'data', 'file=/tmp/tmpym6s_hsl/jm0apmlk.json', 'init=/tmp/tmpym6s_hsl/1suhjerf.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modellxz6kisi/prophet_model-20250531094949.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/tmjlemfy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/nwipjq7n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61835', 'data', 'file=/tmp/tmpym6s_hsl/tmjlemfy.json', 'init=/tmp/tmpym6s_hsl/nwipjq7n.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelwmcbc_p1/prophet_model-20250531094949.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/soblki4a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/i52fz8kq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12003', 'data', 'file=/tmp/tmpym6s_hsl/soblki4a.json', 'init=/tmp/tmpym6s_hsl/i52fz8kq.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model1w9_fien/prophet_model-20250531094950.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/3vdirhzk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/ebll01ty.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28330', 'data', 'file=/tmp/tmpym6s_hsl/3vdirhzk.json', 'init=/tmp/tmpym6s_hsl/ebll01ty.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelxs6kte1q/prophet_model-20250531094950.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/iaihd0uv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/eu1y_kb0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90627', 'data', 'file=/tmp/tmpym6s_hsl/iaihd0uv.json', 'init=/tmp/tmpym6s_hsl/eu1y_kb0.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelt9zggh74/prophet_model-20250531094950.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/hgw2e2mm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/4ni0te46.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64101', 'data', 'file=/tmp/tmpym6s_hsl/hgw2e2mm.json', 'init=/tmp/tmpym6s_hsl/4ni0te46.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_model1_vp3zb3/prophet_model-20250531094951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/37cn1_3p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpym6s_hsl/oe0rdrg3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95844', 'data', 'file=/tmp/tmpym6s_hsl/37cn1_3p.json', 'init=/tmp/tmpym6s_hsl/oe0rdrg3.json', 'output', 'file=/tmp/tmpym6s_hsl/prophet_modelpvoi97t1/prophet_model-20250531094951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ✅ Saved top trending keywords to toptrendingkeywords.json

# %%
generate_recommendations()
# Out:
# Recommended products saved to recommended_products.csv

# %%
# !pip install dash plotly
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.11/dist-packages (from dash) (3.0.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dash) (1.17.0)

# %%
import dash
from dash import html, dcc, dash_table
import plotly.express as px
import pandas as pd
import json

# Import your functions
#import generate_trending_keywords, generate_recommendations

def main():
    # --- 1. Generate Trending Keywords and Recommendations ---
    print("🔍 Generating trending keywords and recommendations...")
    #generate_trending_keywords()
    generate_recommendations()
    print("✅ Data generation complete!")

    # --- 2. Load Processed Data ---
    with open('/content/drive/MyDrive/HackFest_Dataset/toptrendingkeywords.json', 'r') as f:
        trending_keywords = json.load(f)
    df_trending = pd.DataFrame(trending_keywords)

    df_recommendations = pd.read_csv('/content/drive/MyDrive/HackFest_Dataset/recommended_products.csv')

    # --- 3. Create Dash App ---
    app = dash.Dash(__name__)
    app.title = "AI-Powered Trend & Recommendation Dashboard"

    # --- 4. Visualizations ---
    # Top Trending Keywords Bar Chart
    trending_fig = px.bar(
        df_trending,
        x='keyword',
        y='forecast_score',
        title="🔥 Top Trending Keywords Forecast",
        color='forecast_score'
    )

    # Recommended Products Table
    recommendation_table = dash_table.DataTable(
        columns=[{"name": col, "id": col} for col in df_recommendations.columns],
        data=df_recommendations.to_dict('records'),
        page_size=10,
        style_table={'overflowX': 'auto'},
        style_cell={'textAlign': 'left'}
    )

    # --- 5. Layout with Tabs ---
    app.layout = html.Div([
        html.H1("🧠 AI-Powered Trend & Recommendation Dashboard", style={'textAlign': 'center', 'color':'#4A90E2','backgroundColor':'#F5F5F5'}),
        dcc.Tabs([
            dcc.Tab(label='Trending Keywords', children=[
                html.H2("Top 20 Trending Keywords",style={'textAlign': 'center', 'color':'#4A90E2','backgroundColor':'#F5F5F5'}),
                dcc.Graph(figure=trending_fig),
                html.H4("🔍 Data Preview",style={'textAlign': 'center', 'color':'#4A90E2','backgroundColor':'#F5F5F5'}),
                dash_table.DataTable(
                    columns=[{"name": i, "id": i} for i in df_trending.columns],
                    data=df_trending.to_dict('records'),
                    page_size=10,
                    style_table={'overflowX': 'auto'},
                    style_cell={'textAlign': 'left'}
                )
            ]),
            dcc.Tab(label='Products in high Demand', children=[
                html.H2("📦 Recommended Products",style={'textAlign': 'center', 'color':'#4A90E2','backgroundColor':'#F5F5F5'}),
                recommendation_table
            ])
        ])
    ])

    # --- 6. Run App ---
    app.run(debug=True)

if __name__ == "__main__":
    main()
# Out:
# 🔍 Generating trending keywords and recommendations...
# Generating recommendations...
# ✅ Data generation complete!
